# %% [markdown]
# # BME 105
# ## Spring 2026
# ### Homework Assignment 4
#
#
# We will be using this website as a reference:
# https://wmmc.com/understanding-your-lab-results-what-they-mean-for-your-health/
# to build a simple analyzer for interpreting blood test results.
#
#
# ##**Blood Count Basics**
#
# Your blood is made up of different components, each with a specific job to keep your body healthy.
#
#
# *  Red Blood Cells (RBC): These cells carry oxygen from your lungs to the rest of your body.
# *  Hemoglobin (Hgb): This is the protein inside RBCs that binds to oxygen.
# *  Hematocrit (Hct): This measures how much space your RBCs take up in your blood.
# *  Mean Corpuscular Volume (MCV): This measures the size of your RBCs.
# *  White Blood Cells (WBC): Part of your immune system, these cells fight infections. There are five different types of WBCs, and the “differential” count shows how many of each type are in your blood.
# *  Platelets (Plt): These help your blood clot, preventing excessive bleeding.
#
#
#
# ##**Normal Blood Count Levels**
#
# Here's a quick guide to what's normal for each component, though keep in mind that these values can vary based on factors like age and gender:
#
# ```
# Red Blood Cells (RBC): 4-6 million cells per microliter (mcL)
# Hemoglobin (Hgb): 12-17 grams per deciliter (gm/dL)
# Hematocrit (Hct): 36-50%
# Mean Corpuscular Volume (MCV): 80-95 femtoliters
# White Blood Cells (WBC): 4,000-10,000 cells per mcL
# Platelets (Plt): 140,000-450,000 cells per mcL
# ```
#
#
# ###***Interpreting High and Low Blood Counts***
#
# Sometimes, the levels of certain blood components may be higher or lower than normal. Here's what that might mean:
#
# *  **Red Blood Cells (RBC)**
#     * Low: Could indicate anemia (a shortage of red blood cells).
#     * High: May suggest thicker blood, which could increase the risk of clotting.
# *  **Hemoglobin (Hgb)**
#       * Low: Often due to blood loss or anemia.
#       * High: Could be a sign of thicker blood.
# *  **Hematocrit (Hct)**
#      * Low: May suggest anemia.
#      * High: Could point to dehydration.
# *  **Mean Corpuscular Volume (MCV)**
#       * Low: Often linked to iron deficiency or thalassemia.
#       * High: Can indicate vitamin B12 or folate deficiency.
# *  **White Blood Cells (WBC)**
#       * Low: Often a sign of illness or a weakened immune system.
#       * High: Typically shows your body is fighting an infection.
# *  **Platelets (Plt)**
#       * Low: Could be related to medical treatments, such as chemotherapy.
#       * High: May indicate anemia or other conditions.

# %% [markdown]
# Write a function that takes up to 6 parameters. Use default values that's in the **middle** of the ranges provided.
#
# This function should be able to tell the patient what's wrong with them, then identify the cause. Print out the diagnostics of
#
# 1.   What's symptomatically wrong with the patient
# 2.   What the cause is, based on the blood test results
#
# Use something like:
#
# ```
# def function (rbc = 5, hgb = 14.5,... and so on):
#   # Rest of the function goes here
#   # Print out some diagnostics based on the value measured
# ```
#
# **Method 1:**
#
# Enter the patient data as a list.
# ```
# p_data = [12,4,....]
# ```
#
# Suppose I have a patient who has low hemoglobin. (hgb = 10). Their data may look something like this:
# ```
# p_data = [5,10,45,81,6_000,200_000]
# ```
#
# Then, upon running
# ```
# def(p_data)
# ```
# I should get an output as follows:
# ```
# You may have blood loss or anemia.
# Cause: Your hemoglobin is low at 10 gm/dL (Normal: 12-17 grams per deciliter, gm/dL).
# ```
#
# You should print out any problems the patient may have. This means if they have all 6 parameters out of range, you will have 6 pairs of disease/cause printed out.
#
# ---
#
# **_A Sample Code snippet has been provided for you to start_.** <br>
# I **highly** recommend trying on your own on a blank coding block as well.
#
# ---
# Note that two examples of function calls have been provided below:
#
# ```
# blood_test(p_data[0],p_data[1],p_data[2],p_data[3],p_data[4],p_data[5])
# ```
# ```
# blood_test(*p_data)
# ```

# %%
# The code below takes the high and low values in each category and calculates the average from the midpoint of the range.
# You can tinker with it or start fresh to see if you can formulate your own steps to implement the code.
# Make sure to make a local copy for yourself!
rbc_H = 6
rbc_L = 4
rbc_avg = rbc_H+rbc_L
rbc_avg*=0.5

hgb_H = 17
hgb_L = 12
hgb_avg = hgb_H+hgb_L
hgb_avg*=0.5

hct_H = 50
hct_L = 36
hct_avg = hct_H+hct_L
hct_avg*=0.5

mcv_H = 95
mcv_L = 80
mcv_avg = mcv_H+mcv_L
mcv_avg*=0.5

wbc_H = 10_000
wbc_L = 4_000
wbc_avg = wbc_H+wbc_L
wbc_avg*=0.5

plt_H = 450_000
plt_L = 140_000
plt_avg = plt_H+plt_L
plt_avg*=0.5

# %%
def bloodtest(rbc = rbc_avg, hgb = hgb_avg, hct = mcv_avg, mcv = mcv_avg, wbc = wbc_avg, plt = plt_avg  ):
    if (rbc < rbc_L):
        print("")
    if (hgb < hgb_L):
        print("You may have blood loss or anemia")
        print(f"Cause: Your Hemoglobin count is low at {hgb:4.2f} gm/dL (Normal: {hgb_L:4.2f}-{hgb_H:4.2f} grams per deciliter, gm/dL). \n")
    else:
        print("You're in pretty good health!")
    print("Thank you for using our diagnostic tool")

# %%
p_data = [5,10,45,81,6_000,200_000]
blood_test(p_data[0],p_data[1],p_data[2],p_data[3],p_data[4],p_data[5])

# We can use the format below to simplify the above code. Try it.
# blood_test(*p_data)
